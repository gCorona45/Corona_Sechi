# %% [markdown]
# # Proyecto Final: Aprendizaje por Refuerzo
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gCorona45/Corona_Sechi/blob/main/main.ipynb)
#
# **Máster en Inteligencia Artificial - Universidad de Murcia**
# **Curso:** 2025/2026
#
# **Autores:** Corona, Giovanni; Sechi,Michele
# **Grupo:** Corona_Sechi
#
# ---
# **Descripción del Proyecto:**
# Este repositorio contiene la implementación y el análisis experimental de técnicas de Aprendizaje por Refuerzo. El estudio está dividido en la evaluación de algoritmos para el problema del bandido de k-brazos (exploración vs explotación) y el uso de métodos tabulares y aproximados en entornos dinámicos de decisión de Markov (MDP).

# %%
import os
import sys

# Parámetros del repositorio
REPO_URL = "https://github.com/gCorona45/Corona_Sechi.git"
REPO_DIR = "Corona_Sechi"

# Clonación del repositorio si no está presente en el entorno virtual
if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL}
    print(f"Repositorio clonado correctamente en: {REPO_DIR}")
else:
    print("El repositorio ya está presente en el entorno.")

# Cambio del directorio de trabajo a la raíz del proyecto
os.chdir(REPO_DIR)
sys.path.append(os.getcwd())

# !pip install -q gymnasium flappy-bird-gymnasium gym-simplegrid "gymnasium[other]" numpy pandas matplotlib torch tqdm seaborn
print("Dependencias instaladas con éxito. Entorno listo para la ejecución.")
# Out:
# Cloning into 'Corona_Sechi'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 75 (delta 14), reused 40 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 4.19 MiB | 3.04 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# Repositorio clonado correctamente en: Corona_Sechi
# Dependencias instaladas con éxito. Entorno listo para la ejecución.

# %% [markdown]
# ## Índice de Navegación del Proyecto
#
# A continuación se presentan los enlaces directos a los módulos de experimentación. Al hacer clic, se abrirán los cuadernos correspondientes dentro del entorno.
#
# ### 1. [Grupo 1: Aprendizaje en el bandido de k-brazos](k_brazos/main.ipynb)
# Análisis exhaustivo del dilema de exploración-explotación.
# * **Entornos:** Distribuciones Bernoulli, Binomiales y Normales.
# * **Algoritmos analizados:** $\epsilon$-Greedy, $\epsilon$-Decay, UCB1, UCB2, UCB1-Tuned, Softmax y Gradient Bandit.
#
# ### 2. [Grupo 2: Aprendizaje en entornos complejos (Métodos Tabulares y Aproximados)](Entornos_Complejos/main.ipynb)
# Resolución de procesos de decisión secuencial utilizando el entorno Gymnasium.
# * **Métodos Tabulares:** Monte Carlo (On-policy / Off-policy) y Diferencias Temporales (SARSA, Q-Learning).
# * **Métodos Aproximados:** SARSA semi-gradiente y Deep Q-Network (DQN) aplicados a espacios de estados continuos.Q
